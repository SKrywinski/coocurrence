# %% [markdown]
# # Test

# %% [markdown]
# ### packages

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import os
from stop_words import get_stop_words
from collections import Counter 
import time
import pandas as pd

# %% [markdown]
# ### Variablen und Wortlisten

# %%
wiki_pfad = r"D:\informatik_programme\word_embedding\wikipedia_kookurrenz\text"
counter = 0

#with open("r", encoding="utf-8")

stopp_wörter = get_stop_words('de') #type = Liste
satzzeichen = [".", ",", "!", ";", "?", "(", ")", r"'", 
               r"`", ":", r"„", r"''", "%", r"“", "-", 
               "_", r"``", "–", ">", "<", "†", "/"]
weitere_stopp_wörter = ["doc", "ab", "id=", "url=", "https", "title=",
                        "/doc", "*", "seit", "sowie"]

counter_wörterbuch = dict()
wort_von_wiki_counter = 0
start_time = time.time()
dateicounter = 0
alle_sätze_aller_artikel = []

# %% [markdown]
# ### Dictionary der häufigsten Wörter von Wikipedia

# %%
for root, dirs, files in os.walk(wiki_pfad, topdown=True):
    for datei in files:
        dateicounter+=1
        zeit = time.time() - start_time
        if zeit > 60:
            break
        d = str(os.path.join(root, datei))
        with open(d, "r", encoding="utf-8") as artikel:
            text = artikel.read().lower()
            sätze = sent_tokenize(text)
            alle_sätze_aller_artikel.append(sätze)
            for satz in sätze:
                sätze_wörter = word_tokenize(satz)
                
                for wort in sätze_wörter:
                    if wort in stopp_wörter:
                        wort_von_wiki_counter += 1 
                        pass
                    elif wort in weitere_stopp_wörter:
                        wort_von_wiki_counter += 1 
                        pass
                    elif wort in satzzeichen:
                        pass
                    else:
                        wort_von_wiki_counter += 1
                        if wort not in counter_wörterbuch:
                            counter_wörterbuch[wort] = 1
                        else:
                            counter_wörterbuch[wort] += 1
            
            counter += 1
            
print("Anzahl der Wörter: " + str(wort_von_wiki_counter))
print(len(counter_wörterbuch))
print(dateicounter)
# Out:
# Anzahl der Wörter: 3340610
# 266951
# 79

# %% [markdown]
# ### Die n-häufigsten Wörter von Wikipedia

# %%
sorted(counter_wörterbuch.values())
häufigsten_wörter = Counter(counter_wörterbuch).most_common(10000)
häufigsten_wörter_wörterbuch = {}
for tupel in häufigsten_wörter:
    wort = tupel[0]
    häufigkeit = tupel[1]
    häufigsten_wörter_wörterbuch[wort] = häufigkeit
print(häufigsten_wörter)
print(häufigsten_wörter_wörterbuch)
# Out:
# [('wurde', 16895), ('wurden', 6704), ('etwa', 4573), ('jedoch', 3969), ('jahr', 3711), ('jahre', 3422), ('mehr', 3363), ('stadt', 3325), ('zeit', 3299), ('zwei', 3294), ('jahren', 3091), ('ersten', 2932), ('heute', 2882), ('gibt', 2875), ('deutschen', 2546), ('bereits', 2519), ('dabei', 2450), ('später', 2330), ('drei', 2275), ('jahrhundert', 2258), ('weitere', 2201), ('erste', 2193), ('deutschland', 2159), ('erst', 2095), ('teil', 2036), ('z.', 2034), ('neben', 2016), ('menschen', 2016), ('viele', 2000), ('konnte', 1994), ('beim', 1984), ('ende', 1984), ('b.', 1927), ('bezeichnet', 1914), ('deren', 1906), ('bzw', 1902), ('allerdings', 1873), ('immer', 1857), ('beispiel', 1777), ('schon', 1765), ('kam', 1682), ('oft', 1679), ('gab', 1639), ('verwendet', 1638), ('großen', 1603), ('liegt', 1575), ('denen', 1571), ('sei', 1570), ('große', 1570), ('ebenfalls', 1568), ('de', 1567), ('beiden', 1558), ('daher', 1556), ('//de.wikipedia.org/wiki', 1522), ('insbesondere', 1518), ('aufgrund', 1506), ('beispielsweise', 1503), ('gilt', 1483), ('meist', 1480), ('worden', 1473), ('bekannt', 1468), ('neue', 1464), ('form', 1460), ('prozent', 1448), ('zunächst', 1426), ('neuen', 1388), ('vier', 1374), ('deutsche', 1356), ('jahrhunderts', 1334), ('wegen', 1319), ('’', 1317), ('besonders', 1315), ('siehe', 1313), ('zweiten', 1304), ('millionen', 1298), ('zusammen', 1280), ('bedeutung', 1268), ('welt', 1225), ('stark', 1214), ('genannt', 1213), ('mehrere', 1213), ('of', 1210), ('wobei', 1207), ('innerhalb', 1202), ('chr', 1185), ('außerdem', 1177), ('besteht', 1170), ('rund', 1170), ('statt', 1162), ('fast', 1151), ('zurück', 1148), ('the', 1142), ('steht', 1124), ('leben', 1123), ('häufig', 1119), ('film', 1114), ('rolle', 1109), ('führte', 1097), ('1', 1096), ('mai', 1096), ('oktober', 1093), ('august', 1091), ('namen', 1089), ('v.', 1089), ('je', 1082), ('märz', 1080), ('januar', 1078), ('meisten', 1070), ('gegenüber', 1062), ('1.', 1055), ('sprache', 1048), ('begriff', 1046), ('april', 1045), ('weiteren', 1044), ('erstmals', 1038), ('möglich', 1038), ('land', 1024), ('juni', 1022), ('art', 1017), ('entwicklung', 1012), ('dezember', 1011), ('verschiedene', 1005), ('november', 1004), ('frankreich', 995), ('juli', 995), ('verschiedenen', 994), ('september', 992), ('erhielt', 976), ('berlin', 971), ('davon', 969), ('finden', 967), ('19.', 962), ('bevölkerung', 960), ('[', 958), (']', 958), ('reich', 955), ('lassen', 953), ('sowohl', 946), ('insgesamt', 945), ('zudem', 943), ('letzten', 937), ('a', 936), ('tod', 935), ('staaten', 935), ('stand', 933), ('geschichte', 922), ('weniger', 921), ('vielen', 920), ('nachdem', 914), ('europa', 913), ('zahl', 904), ('teilweise', 903), ('begann', 903), ('anfang', 897), ('schließlich', 896), ('fünf', 892), ('bereich', 890), ('usa', 879), ('zahlreiche', 879), ('befindet', 875), ('kommt', 869), ('findet', 861), ('20.', 860), ('kaiser', 852), ('dafür', 844), ('konnten', 844), ('dadurch', 843), ('sprachen', 834), ('regierung', 833), ('lange', 827), ('ließ', 825), ('fand', 823), ('lässt', 821), ('europäischen', 820), ('erhalten', 813), ('jeweils', 813), ('=', 809), ('kirche', 801), ('folgenden', 799), ('darauf', 797), ('deutlich', 792), ('pro', 787), ('eigenen', 786), ('somit', 784), ('februar', 779), ('beide', 779), ('sogar', 776), ('damals', 774), ('2', 773), ('größte', 768), ('ging', 764), ('krieg
 'juni': 1022, 'art': 1017, 'entwicklung': 1012, 'dezember': 1011, 'verschiedene': 1005, 'november': 1004, 'frankreich': 995, 'juli': 995, 'verschiedenen': 994, 'september': 992, 'erhielt': 976, 'berlin': 971, 'davon': 969, 'finden': 967, '19.': 962, 'bevölkerung': 960, '[': 958, ']': 958, 'reich': 955, 'lassen': 953, 'sowohl': 946, 'insgesamt': 945, 'zudem': 943, 'letzten': 937, 'a': 936, 'tod': 935, 'staaten': 935, 'stand': 933, 'geschichte': 922, 'weniger': 921, 'vielen': 920, 'nachdem': 914, 'europa': 913, 'zahl': 904, 'teilweise': 903, 'begann': 903, 'anfang': 897, 'schließlich': 896, 'fünf': 892, 'bereich': 890, 'usa': 879, 'zahlreiche': 879, 'befindet': 875, 'kommt': 869, 'findet': 861, '20.': 860, 'kaiser': 852, 'dafür': 844, 'konnten': 844, 'dadurch': 843, 'sprachen': 834, 'regierung': 833, 'lange': 827, 'ließ': 825, 'fand': 823, 'lässt': 821, 'europäischen': 820, 'erhalten': 813, 'jeweils': 813, '=': 809, 'kirche': 801, 'folgenden': 799, 'darauf': 797, 'deutlich': 792, 'pro': 787, 'eigenen': 786, 'somit': 784, 'februar': 779, 'beide': 779, 'sogar': 776, 'damals': 774, '2': 773, 'größte': 768, 'ging': 764, 'krieg': 761, 'mitte': 757, 'ebenso': 756, 'französischen': 755, 'a.': 748, 'gehört': 747, 'familie': 747, 'erde': 747, 'entstanden': 747, 'arbeit': 745, 'könig': 744, 'ca': 742, 'eingesetzt': 741, 'größten': 741, '‘': 740, 'führt': 738, 'kurz': 729, 'werk': 721, '10': 721, 'eigene': 716, 'wasser': 714, 'darüber': 714, 'heutigen': 713, 'politischen': 712, 'ii': 709, 'gut': 708, 'bilden': 707, 'universität': 705, 'seite': 703, 'entwickelte': 703, 'nahm': 700, 'macht': 699, 'blieb': 699, 'kommen': 695, 'regel': 692, 'neu': 691, 'partei': 689, '2006': 688, 'fall': 686, 'personen': 685, 'friedrich': 684, 'landes': 683, '2007': 682, 'beginn': 682, 'arten': 682, 'euro': 680, 'folge': 679, 'direkt': 678, 'hohen': 678, 'geht': 677, '2008': 674, '20': 674, 'alten': 674, 'darunter': 672, 'rahmen': 671, 'ganz': 669, 'deshalb': 669, 'obwohl': 667, 'bezeichnung': 666, '2011': 666, 'heinrich': 663, 'dagegen': 662, 'entstand': 661, 'gruppe': 660, 'stellte': 658, 'stehen': 655, 'gegensatz': 655, 'gehören': 651, '200 ...

# %% [markdown]
# ### Erstellung der Matrix

# %%
matrix = pd.DataFrame(0, index=häufigsten_wörter_wörterbuch, columns=häufigsten_wörter_wörterbuch)
print(matrix)
matrix.to_csv("matrix.csv")
# Out:
#                   wurde  wurden  etwa  jedoch  jahr  jahre  mehr  stadt  zeit  \
# wurde                 0       0     0       0     0      0     0      0     0
# wurden                0       0     0       0     0      0     0      0     0
# etwa                  0       0     0       0     0      0     0      0     0
# jahr                 0    ...        0            0               0
# jahre                0    ...        0            0               0
# mehr                 0    ...        0            0               0
# stadt                0    ...        0            0               0
# zeit                 0    ...        0            0               0
# zwei                 0    ...        0            0               0
# jahren               0    ...        0            0               0
# ersten               0    ...        0            0               0
# heute                0    ...        0            0               0
# gibt                 0    ...        0            0               0
# deutschen            0    ...        0            0               0
# bereits              0    ...        0            0               0
# dabei                0    ...        0            0               0
# später               0    ...        0            0               0
# drei                 0    ...        0            0               0
# jahrhundert          0    ...        0            0               0
# weitere              0    ...        0            0               0
# erste                0    ...        0            0               0
# deutschland          0    ...        0            0               0
# erst                 0    ...        0            0               0
# teil                 0    ...        0            0               0
# z.                   0    ...        0            0               0
# neben                0    ...        0            0               0
# menschen             0    ...        0            0               0
# viele                0    ...        0            0               0
# konnte               0    ...        0            0               0
# ...                ...    ...      ...          ...             ...
# mechanisch           0    ...        0            0               0
# wohingegen           0    ...        0            0               0
# tragende             0    ...        0            0               0
# hitze                0    ...        0            0               0
# flüssiges            0    ...        0            0               0
# 400.000              0    ...        0            0               0
# kationen             0    ...        0            0               0
# elektroden           0    ...        0            0               0
# nutzbar              0    ...        0            0               0
# festes               0    ...        0            0               0
# schwereren           0    ...        0            0               0
# destillation         0    ...        0            0               0
# 1250                 0    ...        0            0               0
# zeiträume            0    ...        0            0               0
# kruste               0    ...        0            0               0
# lichtes              0    ...        0            0               0
# netzwerke            0    ...        0            0               0
# 175                  0    ...        0            0               0
# langsame             0    ...        0            0               0
# damen                0    ...        0            0               0
# mike                 0    ...        0            0               0
# untergruppe          0    ...        0            0               0
# resultierenden       0    ...        0            0               0
# röntgenstrahlung     0    ...        0            0               0
# stabiler             0    ...        0            0               0
# anteilen             0    ...        0            0               0
# fortlaufend          0    ...        0            0               0
# grundsätzen          0    ...        0            0               0
# deklaration          0    ...        0            0               0
# kliniken             0    ...        0            0               0
#
#                   röntgenstrahlung  stabiler  anteilen  fortlaufend  \
# wurde                            0         0         0            0
# wurden                           0         0         0            0
# etwa                             0         0         0            0
# jedoch                           0         0         0            0
# jahr                             0         0         0            0
# jahre                            0         0         0            0
# mehr                             0         0         0            0
# stadt                            0         0         0            0
# zeit                             0         0         0            0
# zwei                             0         0         0            0
# jahren                           0         0         0            0
# ersten                           0         0         0            0
# heute                            0         0         0            0
# gibt                             0         0         0            0
# deutschen                        0         0         0            0
# bereits                          0         0         0            0
# dabei                            0         0         0            0
# später                           0         0         0            0
# drei                             0         0         0            0
# jahrhundert                      0         0         0            0
# weitere                          0         0         0            0
# erste                            0         0         0            0
# deutschland                      0         0         0            0
# erst                             0         0         0            0
# teil                             0         0         0            0
# z.                               0         0         0            0
# neben                            0         0         0            0
# menschen                         0         0         0            0
# viele                            0         0         0            0
# konnte                           0         0         0            0
# ...                            ...       ...       ...          ...
# mechanisch                       0         0         0            0
# wohingegen                       0         0         0            0
# tragende                         0         0         0            0
# hitze                            0         0         0            0
# flüssiges                        0         0         0            0
# 400.000                          0         0         0            0
# kationen                         0         0         0            0
# elektroden                       0         0         0            0
# nutzbar                          0         0         0            0
# festes                           0         0         0            0
# schwereren                       0         0         0            0
# destillation                     0         0         0            0
# 1250                             0         0         0            0
# zeiträume                        0         0         0            0
# kruste                           0         0         0            0
# lichtes                          0         0         0            0
# netzwerke                        0         0         0            0
# 175                              0         0         0            0
# langsame                         0         0         0            0
# damen                            0         0         0            0
# mike                             0         0         0            0
# untergruppe                      0         0         0            0
# resultierenden                   0         0         0            0
# röntgenstrahlung                 0         0         0            0
# stabiler                         0         0         0            0
# anteilen                         0         0         0            0
# fortlaufend                      0         0         0            0
# grundsätzen                      0         0         0            0
# deklaration                      0         0         0            0
# kliniken                         0         0         0            0
#
#                   grundsätzen  deklaration  kliniken
# wurde                       0            0         0
# wurden                      0            0         0
# etwa                        0            0         0
# jedoch                      0            0         0
# jahr                        0            0         0
# jahre                       0            0         0
# mehr                        0            0         0
# stadt                       0            0         0
# zeit                        0            0         0
# zwei                        0            0         0
# jahren                      0            0         0
# ersten                      0            0         0
# heute                       0            0         0
# gibt                        0            0         0
# deutschen                   0            0         0
# bereits                     0            0         0
# dabei                       0            0         0
# später                      0            0         0
# drei                        0            0         0
# jahrhundert                 0            0         0
# weitere                     0            0         0
# erste                       0            0         0
# deutschland                 0            0         0
# erst                        0            0         0
# teil                        0            0         0
# z.                          0            0         0
# neben                       0            0         0
# menschen                    0            0         0
# viele                       0            0         0
# konnte                      0            0         0
# ...                       ...          ...       ...
# mechanisch                  0            0         0
# wohingegen                  0            0         0
# tragende                    0            0         0
# hitze                       0            0         0
# flüssiges                   0            0         0
# 400.000                     0            0         0
# kationen                    0            0         0
# elektroden                  0            0         0
# nutzbar                     0            0         0
# festes                      0            0         0
# schwereren                  0            0         0
# destillation                0            0         0
# 1250                        0            0         0
# zeiträume                   0            0         0
# kruste                      0            0         0
# lichtes                     0            0         0
# netzwerke                   0            0         0
# 175                         0            0         0
# langsame                    0            0         0
# damen                       0            0         0
# mike                        0            0         0
# untergruppe                 0            0         0
# resultierenden              0            0         0
# röntgenstrahlung            0            0         0
# stabiler                    0            0         0
# anteilen                    0            0         0
# fortlaufend                 0            0         0
# grundsätzen                 0            0         0
# deklaration                 0            0         0
# kliniken                    0            0         0
#
# [10000 rows x 10000 columns]

# %% [markdown]
# # [TO-DO] Daten füllen

# %% [markdown]
# #### TO-DO: nur nachbarn zählen, nicht wort selbst

# %%
#c = Anzahl der Nachbarn einer Seite, string = vortokenisierter satz, k = ergebnis_dictionary
def nachbarn_suchen(nachbarn, string, k={}):
    for n, wort in enumerate(string):
        if n - nachbarn <= 0:
            if wort not in k.keys():
                k[wort] = []
                k[wort] = string[:n+(nachbarn+1)]
            else:
                k[wort] += [string[:n+(nachbarn+1)]]
        elif n + nachbarn > len(string)+1:
            if wort not in k.keys():
                k[wort] = []
                k[wort] = string[n-nachbarn:]
            else:
                k[wort] += string[n-c:]
        else:
            if wort not in k.keys():
                k[wort] = []
                k[wort] = string[n-nachbarn:n+(nachbarn+1)]
            else:
                k[wort] += string[n-nachbarn:n+(nachbarn+1)]
    return k

s = ["jan", "ist", "fast", "so", "gut", "wie", "stefan", "in", "python", ",", "oder", "doch" "nicht" "?"]
s2 = "jan ist fast so gut wie stefan in python, oder doch nicht jan?"
s3 = word_tokenize(s2)
for word in s3:
    if word in satzzeichen:
        s3.remove(word)
#print(s3)

print(nachbarn_suchen(2, s3))
# Out:
# {'jan': ['jan', 'ist', 'fast', 'doch', 'nicht', 'jan'], 'ist': ['jan', 'ist', 'fast', 'so'], 'fast': ['jan', 'ist', 'fast', 'so', 'gut'], 'so': ['ist', 'fast', 'so', 'gut', 'wie'], 'gut': ['fast', 'so', 'gut', 'wie', 'stefan'], 'wie': ['so', 'gut', 'wie', 'stefan', 'in'], 'stefan': ['gut', 'wie', 'stefan', 'in', 'python'], 'in': ['wie', 'stefan', 'in', 'python', 'oder'], 'python': ['stefan', 'in', 'python', 'oder', 'doch'], 'oder': ['in', 'python', 'oder', 'doch', 'nicht'], 'doch': ['python', 'oder', 'doch', 'nicht', 'jan'], 'nicht': ['oder', 'doch', 'nicht', 'jan']}

# %%
meta_dic = {}

#for k,v in häufigsten_wörter_wörterbuch.items():
 #   meta_dic[k] = k
    
#print(meta_dic)

metaliste = []
start_time = time.time()
for datei in alle_sätze_aller_artikel:
    zeit = time.time() - start_time
    if zeit > 3:
        break
    dateiliste = []
    for satz in datei:
        t_satz = word_tokenize(satz)
        for word in t_satz:
            if word in satzzeichen:
                t_satz.remove(word)
            elif word in stopp_wörter:
                t_satz.remove(word)
            elif word in weitere_stopp_wörter:
                t_satz.remove(word)
        dateiliste.append(t_satz)
    metaliste.append(dateiliste)
    
print(metaliste)

"""
nachbar_wörterbuch = None
start_time = time.time()
for datei in alle_sätze_aller_artikel:
    zeit = time.time() - start_time
    if zeit > 3:
        break
    for satz in datei:
        t_satz = word_tokenize(satz)
        for word in t_satz:
            if word in satzzeichen:
                t_satz.remove(word)
            elif word in stopp_wörter:
                t_satz.remove(word)
            elif word in weitere_stopp_wörter:
                t_satz.remove(word)
            #elif word, anzahl in häufigsten_wörter_wörterbuch
        nachbar_wörterbuch = nachbarn_suchen(2, t_satz)
        for k,v in nachbar_wörterbuch.items():
            if k in häufigsten_wörter_wörterbuch.keys():
                if k in meta_dic.keys():
                    meta_dic[k] += v
                else:
                    meta_dic[k] = v
"""
#print(meta_dic)                    
"""        
for k,v in nachbar_wörterbuch.items():
    for liste in v:
        meta_dic[k] = Counter(liste)
"""
      
        
"""
        for k,v in nachbar_wörterbuch.items():
            if k in häufigsten_wörter_wörterbuch:
                if k2,v2 in meta_dic.items():
                    
                    meta_dic[k2] = v + v2 #stimmt? nein bestimmt nicht
                else:
                    meta_dic[k2] = v2
"""

# %%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
